# %% [markdown]
# <a href="https://colab.research.google.com/github/mnocerino23/NBA-Player-Classifier/blob/main/NBA_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Start by reading in datasets containing NBA indiviual per game and advanced stats in addition to salaries for the upcoming 2022-2023 (Following this past Free Agency)
#
#
# 1.   Salaries2022-2023.csv - contains NBA player salaries from the 2022-2023 season (Source: https://hoopshype.com/salaries/players/)
# 2.   2021-2022PerGameStats.csv - contains NBA player per game stats from the 2021-2022 season (Source: https://www.basketball-reference.com/leagues/NBA_2022_per_game.html)
# 3.   2021-2022AdvancedStats.csv - contains NBA player advanced stats for the 2021-2022 season (Source: https://www.basketball-reference.com/leagues/NBA_2022_advanced.html)

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')


nba_salaries = pd.read_csv('/content/drive/MyDrive/Data_Science_Projects/NBA/Salaries2022-2023.csv')
stats_pergame = pd.read_csv('/content/drive/MyDrive/Data_Science_Projects/NBA/2021-2022PerGameStats.csv')
stats_advanced = pd.read_csv('/content/drive/MyDrive/Data_Science_Projects/NBA/2021-2022AdvancedStats.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
nba_salaries = nba_salaries.drop(['Unnamed: 0'], axis = 1)
nba_salaries.rename(columns={'Unnamed: 1': 'Name', '22/23': 'Salary'}, inplace = True)
nba_salaries.head(3)
# Out:
#                 Name    Salary       23/24     24/25     25/26  26/27  27/28
# 0      Stephen Curry  48070014  51915615.0  55761217  59606817      0      0
# 1          John Wall  47345760   6802950.0         0         0      0      0
# 2  Russell Westbrook  47063478         0.0         0         0      0      0

# %%
#convert the 22/23 salary to millions
#first we must cast the salary type to float so that we can get decimals when we divide all by 1,000,000

nba_salaries = nba_salaries.astype({'Salary':'float'})

# %%
for index, row in nba_salaries.iterrows():
  nba_salaries.at[index, 'Salary'] =  nba_salaries.at[index, 'Salary'] * (1/1000000)

# %%
nba_salaries = nba_salaries[['Name','Salary']]
nba_salaries.head(10)
# Out:
#                     Name     Salary
# 0          Stephen Curry  48.070014
# 1              John Wall  47.345760
# 2      Russell Westbrook  47.063478
# 3           LeBron James  44.474988
# 4           Kevin Durant  44.119845
# 5           Bradley Beal  43.279250
# 6            Paul George  42.492568
# 7          Kawhi Leonard  42.492492
# 8  Giannis Antetokounmpo  42.492492
# 9         Damian Lillard  42.492492

# %%
nba_salaries.describe().transpose()
# Out:
#         count      mean        std       min       25%     50%        75%  \
# Salary  521.0  8.573552  10.454204  0.092857  1.846738  3.9186  10.900634
#
#               max
# Salary  48.070014

# %% [markdown]
# # Create a Dictionary Mapping Player Name to 2022-2023 Salary

# %%
season_salaries = dict(zip(nba_salaries['Name'],nba_salaries['Salary']))
print(season_salaries)
# Out:
# {'Stephen Curry': 48.070014, 'John Wall': 47.34576, 'Russell Westbrook': 47.063477999999996, 'LeBron James': 44.474987999999996, 'Kevin Durant': 44.119845, 'Bradley Beal': 43.27925, 'Paul George': 42.492568, 'Kawhi Leonard': 42.492492, 'Giannis Antetokounmpo': 42.492492, 'Damian Lillard': 42.492492, 'Klay Thompson': 40.60008, 'Rudy Gobert': 38.172413999999996, 'Khris Middleton': 37.984276, 'Anthony Davis': 37.98072, 'Jimmy Butler': 37.6533, 'Tobias Harris': 37.63305, 'Trae Young': 37.0965, 'Zach LaVine':
14.317459, 'Wendell Carter': 14.149999999999999, 'Kentavious Caldwell-Pope': 14.004703, 'Brook Lopez': 13.906976, 'Doug McDermott': 13.75, 'Luke Kennard': 13.745455, 'Zion Williamson': 13.534816999999999, 'Jordan Clarkson': 13.34, 'Gary Harris': 13.0, 'Kyle Kuzma': 13.0, 'Patrick Beverley': 13.0, 'Josh Hart': 12.959999999999999, 'Kelly Olynyk': 12.804877999999999, 'Chris Boucher': 12.69, 'Kelly Oubre': 12.6, 'Marvin Bagley': 12.5, 'Dorian Finney-Smith': 12.402, 'Robert Covington': 12.307692, 'Josh Richardson': 12.196093999999999, 'Ja Morant': 12.119439999999999, 'Devonte Graham': 11.549999999999999, 'Terrence Ross': 11.5, 'Dillon Brooks': 11.4, 'Richaun Holmes': 11.215259999999999, 'Reggie Jackson': 11.215259999999999, 'Dwight Powell': 11.080124999999999, 'Paolo Banchero': 11.055119999999999, 'Robert Williams': 10.937502, 'RJ Barrett': 10.900634, 'Bobby Portis': 10.84335, 'DeAndre Jordan': 10.733758, 'Anthony Edwards': 10.7334, ...

# %% [markdown]
# # Now take a look at the other two datasets. We will eventually combine them into one larger stats dataframe

# %%
stats_pergame.columns
# Out:
# Index(['0', 'Player', 'Position', 'Age', 'Team', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
stats_pergame = stats_pergame.drop(['0'], axis = 1)
stats_pergame.head(10)
# Out:
#                      Player Position  Age Team   G  GS    MP   FG   FGA  \
# 0          Precious Achiuwa        C   22  TOR  73  28  23.6  3.6   8.3
# 1              Steven Adams        C   28  MEM  76  75  26.3  2.8   5.1
# 2               Bam Adebayo        C   24  MIA  56  56  32.6  7.3  13.0
# 3              Santi Aldama       PF   21  MEM  32   0  11.3  1.7   4.1
# 4         LaMarcus Aldridge        C   36  BRK  47  12  22.3  5.4   9.7
# 5  Nickeil Alexander-Walker       SG   23  TOT  65  21  22.6  3.9  10.5
# 6  Nickeil Alexander-Walker       SG   23  NOP  50  19  26.3  4.7  12.6
# 7  Nickeil Alexander-Walker       SG   23  UTA  15   2   9.9  1.1   3.2
# 8             Grayson Allen       SG   26  MIL  66  61  27.3  3.9   8.6
# 9             Jarrett Allen        C   23  CLE  56  56  32.3  6.6   9.7
#
#      FG%  ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.439  ...  0.595  2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1  0.547  ...  0.543  4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2  0.557  ...  0.753  2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3  0.402  ...  0.625  1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4  0.550  ...  0.873  1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
# 5  0.372  ...  0.743  0.6  2.3   2.9  2.4  0.7  0.4  1.4  1.6  10.6
# 6  0.375  ...  0.722  0.7  2.6   3.3  2.8  0.8  0.4  1.7  1.8  12.8
# 7  0.333  ...  0.917  0.1  1.5   1.5  1.1  0.3  0.3  0.5  1.0   3.5
# 8  0.448  ...  0.865  0.5  2.9   3.4  1.5  0.7  0.3  0.7  1.5  11.1
# 9  0.677  ...  0.708  3.4  7.3  10.8  1.6  0.8  1.3  1.7  1.7  16.1
#
# [10 rows x 29 columns]

# %%
stats_pergame.shape
# Out:
# (812, 29)

# %%
stats_advanced.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Position', 'Age', 'Team', 'G', 'MP', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
#        'VORP'],
#       dtype='object')

# %%
stats_advanced = stats_advanced.drop(['Unnamed: 0', 'Age' ,'Position', 'Team', 'G', 'MP'], axis = 1)
stats_advanced.rename(columns={'Player': 'Name'}, inplace = True)
stats_advanced.head(10)
# Out:
#                        Name   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  \
# 0          Precious Achiuwa  12.7  0.503  0.259  0.217   8.7  21.7  14.9
# 1              Steven Adams  17.6  0.560  0.003  0.518  17.9  22.0  19.9
# 2               Bam Adebayo  21.8  0.608  0.008  0.466   8.7  26.1  17.5
# 3              Santi Aldama  10.2  0.452  0.364  0.242   9.4  16.1  12.6
# 4         LaMarcus Aldridge  19.6  0.604  0.100  0.223   7.8  18.7  13.4
# 5  Nickeil Alexander-Walker  10.5  0.475  0.497  0.160   2.7  11.5   7.1
# 6  Nickeil Alexander-Walker  10.5  0.474  0.483  0.153   3.0  11.0   6.9
# 7  Nickeil Alexander-Walker  10.2  0.497  0.688  0.250   0.8  15.6   8.5
# 8             Grayson Allen  12.7  0.609  0.684  0.130   1.9  10.9   6.5
# 9             Jarrett Allen  23.0  0.698  0.018  0.428  12.0  24.5  18.4
#
#    AST%  STL%  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0   6.9   1.1  ...  11.3  18.5  0.4  2.1  2.5  0.070  -2.0  -0.6 -2.6  -0.2
# 1  16.1   1.6  ...  19.6  12.0  3.8  3.0  6.8  0.163   1.0   1.0  2.0   2.0
# 2  17.5   2.2  ...  14.4  25.0  3.6  3.5  7.2  0.188   1.7   2.1  3.8   2.7
# 3   7.7   0.8  ...   9.9  18.4 -0.1  0.4  0.3  0.044  -4.2  -1.5 -5.7  -0.3
# 4   6.3   0.6  ...   8.0  22.4  2.1  1.0  3.1  0.141   1.3  -0.6  0.7   0.7
# 5  16.1   1.5  ...  11.3  24.1 -1.1  1.1  0.1  0.003  -1.8  -1.1 -2.9  -0.3
# 6  16.1   1.5  ...  11.2  24.8 -1.1  0.9 -0.1 -0.005  -1.7  -1.3 -3.0  -0.3
# 7  15.5   1.7  ...  13.1  17.9  0.0  0.2  0.2  0.070  -2.9   1.2 -1.7   0.0
# 8   7.6   1.2  ...   6.7  15.2  2.8  1.4  4.2  0.110   0.6  -0.2  0.4   1.1
# 9   8.2   1.2  ...  12.7  18.1  5.4  3.0  8.5  0.225   2.7   1.2  3.9   2.7
#
# [10 rows x 21 columns]

# %%
stats_advanced.shape
# Out:
# (812, 21)

# %% [markdown]
# # Since the datasets are both from basketball reference and have the same ordering of players, we can join them directly. We keep the player name in both datasets so that we can double check that this join has been done correctly after doing so.

# %%
#Join the two dataframes by adding on the columns of stats advanced to the existing stats per game dataframe
stats_complete = pd.concat([stats_pergame, stats_advanced], axis=1)

# %%
stats_complete.head(5)
# Out:
#               Player Position  Age Team   G  GS    MP   FG   FGA    FG%  ...  \
# 0   Precious Achiuwa        C   22  TOR  73  28  23.6  3.6   8.3  0.439  ...
# 1       Steven Adams        C   28  MEM  76  75  26.3  2.8   5.1  0.547  ...
# 2        Bam Adebayo        C   24  MIA  56  56  32.6  7.3  13.0  0.557  ...
# 3       Santi Aldama       PF   21  MEM  32   0  11.3  1.7   4.1  0.402  ...
# 4  LaMarcus Aldridge        C   36  BRK  47  12  22.3  5.4   9.7  0.550  ...
#
#    TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  11.3  18.5  0.4  2.1  2.5  0.070  -2.0  -0.6 -2.6  -0.2
# 1  19.6  12.0  3.8  3.0  6.8  0.163   1.0   1.0  2.0   2.0
# 2  14.4  25.0  3.6  3.5  7.2  0.188   1.7   2.1  3.8   2.7
# 3   9.9  18.4 -0.1  0.4  0.3  0.044  -4.2  -1.5 -5.7  -0.3
# 4   8.0  22.4  2.1  1.0  3.1  0.141   1.3  -0.6  0.7   0.7
#
# [5 rows x 50 columns]

# %%
#checking the shape of the new stats dataframe. It is still 812 which is a good sign but we will double check
stats_complete.shape
# Out:
# (812, 50)

# %%
for index, row in stats_complete.iterrows():
  #print(stats_complete.at[index,'Player'], stats_complete.at[index,'Name'])
  #check the consistency of the names at each index, and add the print statement. Nothing is printed so we know merge was as desired
  if stats_complete.at[index,'Player'] != stats_complete.at[index,'Name']:
    print('MERGE IS INCORRECT')

# %%
stats_complete = stats_complete.drop(['Name'], axis = 1)

# %%
#columns of the joined dataset
stats_complete.columns
# Out:
# Index(['Player', 'Position', 'Age', 'Team', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM',
#        'BPM', 'VORP'],
#       dtype='object')

# %%
#use the describe function to get an idea of the distribution of the features in the dataset
stats_complete.describe().transpose()
# Out:
#        count       mean        std     min       25%     50%       75%  \
# Age    812.0  26.051724   4.059640  19.000  23.00000  25.000  29.00000
# G      812.0  36.704433  25.899099   1.000  12.00000  36.500  61.00000
# GS     812.0  16.672414  23.817195   0.000   0.00000   4.000  25.00000
# MP     812.0  18.265394   9.648292   1.000  10.50000  17.500  25.72500
# FG     812.0   2.869951   2.223988   0.000   1.20000   2.400   3.90000
# FGA    812.0   6.386576   4.651121   0.000   3.00000   5.150   8.72500
# FG%    797.0   0.434257   0.137794   0.000   0.38500   0.441   0.50000
# 3P     812.0   0.871305   0.841935   0.000   0.20000   0.700   1.40000
# 3PA    812.0   2.560591   2.205642   0.000   0.80000   2.050   3.90000
# 3P%    740.0   0.303445   0.138111   0.000   0.25875   0.331   0.37625
# 2P     812.0   2.000123   1.762505   0.000   0.70000   1.500   2.80000
# 2PA    812.0   3.828695   3.192736   0.000   1.40000   3.000   5.10000
# 2P%    784.0   0.505523   0.157911   0.000   0.45075   0.516   0.57925
# eFG%   797.0   0.497483   0.142109   0.000   0.46400   0.517   0.56300
# FT     812.0   1.204433   1.287991   0.000   0.40000   0.900   1.60000
# FTA    812.0   1.575246   1.585894   0.000   0.50000   1.200   2.00000
# FT%    715.0   0.747571   0.156305   0.000   0.67350   0.765   0.84600
# ORB    812.0   0.812931   0.744196   0.000   0.30000   0.600   1.10000
# DRB    812.0   2.519828   1.790656   0.000   1.30000   2.300   3.40000
# TRB    812.0   3.331650   2.352818   0.000   1.70000   2.900   4.40000
# AST    812.0   1.808251   1.838080   0.000   0.50000   1.200   2.40000
# STL    812.0   0.582759   0.425452   0.000   0.30000   0.500   0.90000
# BLK    812.0   0.353571   0.360811   0.000   0.10000   0.300   0.50000
# TOV    812.0   0.978695   0.817941   0.000   0.40000   0.800   1.30000
# PF     812.0   1.564655   0.826783   0.000   1.00000   1.600   2.20000
# PTS    812.0   7.812438   6.138077   0.000   3.30000   6.300  10.60000
# PER    812.0  12.218719   7.749585 -45.200   9.30000  12.500  16.00000
# TS%    799.0   0.527232   0.139421   0.000   0.49550   0.548   0.59300
# 3PAr   797.0   0.400491   0.236042   0.000   0.25000   0.403   0.56300
# FTr    797.0   0.248739   0.222867   0.000   0.12600   0.220   0.31400
# ORB%   812.0   5.402709   5.665091   0.000   1.87500   3.500   7.60000
# DRB%   812.0  14.759360   7.648939   0.000  10.50000  13.400  18.70000
# TRB%   812.0  10.085345   5.636559   0.000   6.50000   8.700  13.20000
# AST%   812.0  12.868473   9.796030   0.000   6.60000  10.300  17.30000
# STL%   812.0   1.591872   1.731690   0.000   0.90000   1.400   1.90000
# BLK%   812.0   1.753695   1.943327   0.000   0.60000   1.300   2.40000
# TOV%   799.0  12.219274   7.197791   0.000   8.80000  11.500  14.95000
# USG%   812.0  18.014409   6.287915   0.000  14.30000  17.500  21.30000
# OWS    812.0   0.887685   1.534461  -3.000   0.00000   0.200   1.30000
# DWS    812.0   0.821305   0.925846  -0.100   0.10000   0.500   1.20000
# WS     812.0   1.712808   2.291841  -1.600   0.10000   0.800   2.60000
# WS/48  812.0   0.065845   0.131741  -1.231   0.03100   0.079   0.12425
# OBPM   812.0  -1.998030   4.440740 -33.900  -3.52500  -1.500   0.20000
# DBPM   812.0  -0.403325   2.291108 -14.500  -1.30000  -0.300   0.60000
# BPM    812.0  -2.399877   5.746366 -42.600  -4.32500  -1.700   0.30000
# VORP   812.0   0.397044   1.020211  -1.200  -0.10000   0.000   0.50000
#
#            max
# Age     41.000
# G       82.000
# GS      82.000
# MP      43.500
# FG      11.400
# FGA     21.800
# FG%      1.000
# 3P       4.500
# 3PA     11.700
# 3P%      1.000
# 2P       9.500
# 2PA     18.300
# 2P%      1.000
# eFG%     1.000
# FT       9.600
# FTA     11.800
# FT%      1.000
# ORB      4.600
# DRB     11.000
# TRB     14.700
# AST     10.800
# STL      2.500
# BLK      2.800
# TOV      4.800
# PF       5.000
# PTS     30.600
# PER     76.200
# TS%      1.000
# 3PAr     1.000
# FTr      2.000
# ORB%    56.600
# DRB%   100.000
# TRB%    54.500
# AST%   100.000
# STL%    25.000
# BLK%    30.000
# TOV%    58.100
# USG%    54.600
# OWS     10.800
# DWS      4.600
# WS      15.200
# WS/48    1.204
# OBPM    31.000
# DBPM    13.400
# BPM     36.900
# VORP     9.800

# %%
print(list(nba_salaries['Name']))
# Out:
iddie', 'Donte DiVincenzo', 'Donte DiVincenzo', 'Donte DiVincenzo', 'Luka Dončić', 'Luguentz Dort', 'Ayo Dosunmu', 'Damyean Dotson', 'Devon Dotson', 'Sekou Doumbouya', 'Jeff Dowtin', 'Jeff Dowtin', 'Jeff Dowtin', 'Jeff Dowtin', 'PJ Dozier', 'Goran Dragić', 'Goran Dragić', 'Goran Dragić', 'Andre Drummond', 'Andre Drummond', 'Andre Drummond', 'Chris Duarte', 'David Duke Jr.', 'Kris Dunn', 'Kevin Durant', 'Jaime Echenique', 'Anthony Edwards', 'Carsen Edwards', 'Kessler Edwards', 'Rob Edwards', 'CJ Elleby', 'Wayne Ellington', 'Joel Embiid', 'James Ennis III', 'James Ennis III', 'James Ennis III', 'James Ennis III', 'Drew Eubanks', 'Drew Eubanks', 'Drew Eubanks', 'Tacko Fall', 'Derrick Favors', 'Bruno Fernando', 'Bruno Fernando', 'Bruno Fernando', 'Dorian Finney-Smith', 'Malik Fitts', 'Malik Fitts', 'Malik Fitts', 'Malachi Flynn', 'Bryn Forbes', 'Bryn Forbes', 'Bryn Forbes', 'Aleem  ...

# %%
#see how many names are not in the stats_complete dataframe

#after doing some digging, I found that the names printed below have naming inconsistencies due to special characters
#in the last names of many eastern european players, didn't play in the 2021-2022 season (have no stats), have or do not have a consistent suffix (sr/jr),
#have an abbreviated first name, or some other form of naming inconsistency between the two datasets
for item in season_salaries.keys():
  if item not in list(stats_complete['Player']):
    print(item)
# Out:
# John Wall
# Kawhi Leonard
# Luka Doncic
# Ben Simmons
# Kristaps Porzingis
# Nikola Jokic
# Jamal Murray
# Michael Porter
# Jaren Jackson Jr
# Nikola Vucevic
# Tim Hardaway Jr
# Bojan Bogdanovic
# Bogdan Bogdanovic
# Gary Trent Jr
# Jonathan Isaac
# Davis Bertans
# Jusuf Nurkic
# Jonas Valanciunas
# Wendell Carter
# Zion Williamson
# Kelly Oubre
# Marvin Bagley
# Devonte Graham
# Paolo Banchero
# PJ Tucker
# Chet Holmgren
# Larry Nance Jr
# James Wiseman
# Dario Saric
# Jabari Smith
# Nicolas Claxton
# TJ McConnell
# Keegan Murray
# Jaden Ivey
# Bennedict Mathurin
# Patrick Mills
# Lonnie Walker
# Shaedon Sharpe
# Otto Porter
# PJ Washington
# Dyson Daniels
# Kendrick Nunn
# Jeremy Sochan
# Johnny Davis
# Ishmael Smith
# Ousmane Dieng
# Moe Harkless
# Jalen Williams
# Josh Primo
# Jalen Duren
# Danuel House
# Kira Lewis
# Ochai Agbaji
# Mark Williams
# AJ Griffin
# Boban Marjanovic
# Alperen Sengun
# Tari Eason
# Kevin Porter
# Trey Murphy
# Simone Fontecchio
# Derrick Jones
# Dalen Terry
# Jake LaRavia
# Malaki Branham
# Goran Dragic
# Andrew Nicholson
# Christian Braun
# Walker Kessler
# TJ Warren
# Matthew Dellavedova
# David Roddy
# MarJon Beauchamp
# Willy Hernangomez
# RJ Hampton
# Blake Wesley
# Wendell Moore
# Juan Hernangomez
# Andrew Nembhard
# Nikola Jovic
# Vlatko Cancar
# Patrick Baldwin
# TyTy Washington
# Peyton Watson
# DJ Wilson
# Santiago Aldama
# Jaylin Williams
# Edmond Sumner
# Troy Brown
# Theo Maledon
# Sviatoslav Mykhailiuk
# Luca Vildoza
# Herb Jones
# KJ Martin
# Xavier Tillman
# Vernon Carey
# McKinley Wright
# BJ Boston
# Jason Preston
# Greg Brown
# Kennedy Chandler
# Zhaire Smith
# Tyrese Martin
# Jaden Hardy
# Ryan Rollins
# Max Christie
# Josh Minott
# Jabari Walker
# Chima Moneke
# Javon Freeman-Liberty
# Mouhamadou Gueye
# Adonis Arms
# Kellan Grady
# Pat Spencer
# Trevion Williams
# Javante McCoy
# Fabian White
# Jamaree Bouyea
# Jamal Cain
# Orlando Robinson
# Isaiah Miller
# Jared Rhoden
# Gabe Brown
# Matur Maker
# Kyle Singler
# Cole Swider
# Vince Williams Jr
# Kevon Harris
# JD Davison
# Mfiondu Kabengele
# Alondes Williams
# Bryce McGowens
# Justin Lewis
# Isaiah Mobley
# RJ Nembhard
# Collin Gillespie
# Jack White
# Buddy Boeheim
# Lester Quinones
# Trevor Hudgins
# Moussa Diabate
# Scottie Pippen Jr
# Kenneth Lofton
# Darius Days
# AJ Green
# AJ Lawson
# Trevor Keels
# Julian Champagnie
# Duane Washington Jr
# Keon Ellis
# Dominick Barlow
# Jordan Hall
# Ron Harper Jr
# Johnny Juzang
# Chaundee Brown
# Charlie Brown
# DJ Augustin
# Ishmail Wainright
# Troy Williams
# Demetrius Jackson

# %% [markdown]
# # By doing some investigation we see that a variety of naming inconsistencies between the datasets are causing issues when we try to map each name to its salary

# %% [markdown]
# Because there are many naming inconsistencies present, I think the easiest thing to do is add on salary for the consistent names then manually enter the missing values where possible (should be quick)

# %%
stats_complete['Salary'] = float('nan')

# %%
for index, row in stats_complete.iterrows():
  if stats_complete.at[index,'Player'] in season_salaries.keys():
    stats_complete.at[index,'Salary'] = season_salaries[stats_complete.at[index,'Player']]

# %%
#write the results to csv and then fill in missing
stats_complete.to_csv('stats_complete_withnulls.csv', index = False)

# %%
nba_salaries.to_csv('salaries.csv', index = False)

# %% [markdown]
# # Now read back in the stats_complete dataframe that has manually entered salaries for players that were missing salary

# %%
stats_with_salary = pd.read_csv('/content/drive/MyDrive/Data_Science_Projects/NBA/stats_complete_with_salary.csv')

# %%
#players with NaN salaries are NBA players who played in the 2021-2022 season but did not receive contracts for the 2022-2023 season
stats_with_salary.head(5)
# Out:
#               Player Position  Age Team   G  GS    MP   FG   FGA    FG%  ...  \
# 0   Precious Achiuwa        C   22  TOR  73  28  23.6  3.6   8.3  0.439  ...
# 1       Steven Adams        C   28  MEM  76  75  26.3  2.8   5.1  0.547  ...
# 2        Bam Adebayo        C   24  MIA  56  56  32.6  7.3  13.0  0.557  ...
# 3       Santi Aldama       PF   21  MEM  32   0  11.3  1.7   4.1  0.402  ...
# 4  LaMarcus Aldridge        C   36  BRK  47  12  22.3  5.4   9.7  0.550  ...
#
#    USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP     Salary
# 0  18.5  0.4  2.1  2.5  0.070  -2.0  -0.6 -2.6  -0.2   2.840160
# 1  12.0  3.8  3.0  6.8  0.163   1.0   1.0  2.0   2.0  17.926829
# 2  25.0  3.6  3.5  7.2  0.188   1.7   2.1  3.8   2.7  30.351780
# 3  18.4 -0.1  0.4  0.3  0.044  -4.2  -1.5 -5.7  -0.3   2.094120
# 4  22.4  2.1  1.0  3.1  0.141   1.3  -0.6  0.7   0.7        NaN
#
# [5 rows x 50 columns]

# %%
#investigate the presence of nulls within the dataset
stats_with_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 50 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Player    812 non-null    object
#  1   Position  812 non-null    object
#  2   Age       812 non-null    int64
#  3   Team      812 non-null    object
#  4   G         812 non-null    int64
#  5   GS        812 non-null    int64
#  6   MP        812 non-null    float64
#  7   FG        812 non-null    float64
#  8   FGA       812 non-null    float64
#  9   FG%       797 non-null    float64
#  10  3P        812 non-null    float64
#  11  3PA       812 non-null    float64
#  12  3P%       740 non-null    float64
#  13  2P        812 non-null    float64
#  14  2PA       812 non-null    float64
#  15  2P%       784 non-null    float64
#  16  eFG%      797 non-null    float64
#  17  FT        812 non-null    float64
#  18  FTA       812 non-null    float64
#  19  FT%       715 non-null    float64
#  20  ORB       812 non-null    float64
#  21  DRB       812 non-null    float64
#  22  TRB       812 non-null    float64
#  23  AST       812 non-null    float64
#  24  STL       812 non-null    float64
#  25  BLK       812 non-null    float64
#  26  TOV       812 non-null    float64
#  27  PF        812 non-null    float64
#  28  PTS       812 non-null    float64
#  29  PER       812 non-null    float64
#  30  TS%       799 non-null    float64
#  31  3PAr      797 non-null    float64
#  32  FTr       797 non-null    float64
#  33  ORB%      812 non-null    float64
#  34  DRB%      812 non-null    float64
#  35  TRB%      812 non-null    float64
#  36  AST%      812 non-null    float64
#  37  STL%      812 non-null    float64
#  38  BLK%      812 non-null    float64
#  39  TOV%      799 non-null    float64
#  40  USG%      812 non-null    float64
#  41  OWS       812 non-null    float64
#  42  DWS       812 non-null    float64
#  43  WS        812 non-null    float64
#  44  WS/48     812 non-null    float64
#  45  OBPM      812 non-null    float64
#  46  DBPM      812 non-null    float64
#  47  BPM       812 non-null    float64
#  48  VORP      812 non-null    float64
#  49  Salary    509 non-null    float64
# dtypes: float64(44), int64(3), object(3)
# memory usage: 317.3+ KB

# %%
#we will drop all rows with null values from the complete stats dataset

# %%
stats_with_salary = stats_with_salary.dropna()
stats_with_salary.reset_index()
# Out:
#      index                    Player Position  Age Team   G  GS    MP   FG  \
# 0        0          Precious Achiuwa        C   22  TOR  73  28  23.6  3.6
# 1        1              Steven Adams        C   28  MEM  76  75  26.3  2.8
# 2        2               Bam Adebayo        C   24  MIA  56  56  32.6  7.3
# 3        3              Santi Aldama       PF   21  MEM  32   0  11.3  1.7
# 4        5  Nickeil Alexander-Walker       SG   23  TOT  65  21  22.6  3.9
# ..     ...                       ...      ...  ...  ...  ..  ..   ...  ...
# 463    805            Thaddeus Young       PF   33  TOT  52   1  16.3  2.7
# 464    806            Thaddeus Young       PF   33  SAS  26   1  14.2  2.8
# 465    807            Thaddeus Young       PF   33  TOR  26   0  18.3  2.6
# 466    808                Trae Young       PG   23  ATL  76  76  34.9  9.4
# 467    809            Omer Yurtseven        C   23  MIA  56  12  12.6  2.3
#
#       FGA  ...  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP     Salary
# 0     8.3  ...  18.5  0.4  2.1   2.5  0.070  -2.0  -0.6 -2.6  -0.2   2.840160
# 1     5.1  ...  12.0  3.8  3.0   6.8  0.163   1.0   1.0  2.0   2.0  17.926829
# 2    13.0  ...  25.0  3.6  3.5   7.2  0.188   1.7   2.1  3.8   2.7  30.351780
# 3     4.1  ...  18.4 -0.1  0.4   0.3  0.044  -4.2  -1.5 -5.7  -0.3   2.094120
# 4    10.5  ...  24.1 -1.1  1.1   0.1  0.003  -1.8  -1.1 -2.9  -0.3   5.009633
# ..    ...  ...   ...  ...  ...   ...    ...   ...   ...  ...   ...        ...
# 463   5.2  ...  17.4  0.9  1.3   2.2  0.126   0.1   2.1  2.2   0.9   8.000000
# 464   4.9  ...  19.1  0.5  0.5   1.0  0.124   0.5   1.8  2.4   0.4   8.000000
# 465   5.5  ...  16.0  0.5  0.8   1.3  0.127  -0.2   2.2  2.0   0.5   8.000000
# 466  20.3  ...  34.4  9.0  1.0  10.0  0.181   7.1  -2.0  5.2   4.8  37.096500
# 467   4.4  ...  19.9  0.8  1.4   2.1  0.145  -1.4   0.4 -1.0   0.2   1.752638
#
# [468 rows x 51 columns]

# %%
#shape of the dataframe after dropping rows with null values
stats_with_salary.shape
# Out:
# (468, 50)

# %% [markdown]
# # Having dropped null values within the dataset, we have to take care of a few more cleaning tasks

# %% [markdown]
# Things that need to be dealt with
#
# *   Players who were traded during the 2021-2022 season have at least 3 entries (their total stats from the year and their stats from each of the two or more teams they played for). We wan't to only keep their total stats for the season
#
# *   Some Players have multiple positions so we will need to find an effective way to handle that

# %%
#we will first loop through the dataframe, to find all player names that have team (TOT)

# %%
traded_players = []

for index, row in stats_with_salary.iterrows():
  if stats_with_salary.at[index,'Team'] == 'TOT':
    traded_players.append(stats_with_salary.at[index,'Player'])

# %%
print(len(traded_players))
traded_players
# Out:
# 51
# ['Nickeil Alexander-Walker',
#  'D.J. Augustin',
#  'Marvin Bagley III',
#  'DÄ\x81vis BertÄ\x81ns',
#  'Charlie Brown Jr.',
#  'Chaundee Brown Jr.',
#  'Jevon Carter',
#  'Robert Covington',
#  'Torrey Craig',
#  'Seth Curry',
#  'Spencer Dinwiddie',
#  'Donte DiVincenzo',
#  'Jeff Dowtin',
#  'Goran DragiÄ‡',
#  'Andre Drummond',
#  'Drew Eubanks',
#  'Bruno Fernando',
#  'Bryn Forbes',
#  'Wenyen Gabriel',
#  'Tyrese Haliburton',
#  'James Harden',
#  'Josh Hart',
#  'Juancho HernangÃ³mez',
#  'Buddy Hield',
#  'Aaron Holiday',
#  'Justin Holiday',
#  'Danuel House Jr.',
#  'Serge Ibaka',
#  'Keon Johnson',
#  'Braxton Key',
#  'Kevin Knox',
#  'Luke Kornet',
#  'Romeo Langford',
#  'Caris LeVert',
#  'Didi Louzada',
#  'Trey Lyles',
#  'Mac McClung',
#  'CJ McCollum',
#  'Larry Nance Jr.',
#  'Kristaps PorziÅ†Ä£is',
#  'Norman Powell',
#  'Cam Reddish',
#  'Josh Richardson',
#  'Domantas Sabonis',
#  'Ish Smith',
#  'Jalen Smith',
#  'Nik Stauskas',
#  'Daniel Theis',
#  'Derrick White',
#  'Justise Winslow',
#  'Thaddeus Young']

# %%
for index, row in stats_with_salary.iterrows():
  #if the player was traded and the row does not have team = TOT (the players total season stats), we delete the row
  if stats_with_salary.at[index,'Player'] in traded_players and stats_with_salary.at[index,'Team'] != 'TOT':
    stats_with_salary.drop(labels = index, axis = 0, inplace = True)
stats_cleaned = stats_with_salary.reset_index(drop = 'True')

# %%
stats_cleaned.shape
# Out:
# (393, 50)

# %%
#examine the value counts by position throughout the league
print(stats_cleaned['Position'].value_counts())
# Out:
# SG       100
# PF        80
# SF        71
# C         67
# PG        66
# SG-SF      2
# SG-PG      2
# SF-SG      2
# PG-SG      1
# C-PF       1
# PF-C       1
# Name: Position, dtype: int64

# %%
#because very few players have multiple positions in the dataset, we will instead cut down to the primary position (first position given)
#use this loop to get just the primary position
for index, row in stats_cleaned.iterrows():
  pos = stats_cleaned.at[index,'Position']
  if len(pos) > 2:
    if pos[0] == 'C':
      new_pos = 'C'
    else:
      new_pos = pos[0:2]
    stats_cleaned.at[index,'Position'] = new_pos

# %%
print(stats_cleaned['Position'].value_counts())
# Out:
# SG    104
# PF     81
# SF     73
# C      68
# PG     67
# Name: Position, dtype: int64

# %%
stats_cleaned.head(5)
# Out:
#                      Player Position  Age Team   G  GS    MP   FG   FGA  \
# 0          Precious Achiuwa        C   22  TOR  73  28  23.6  3.6   8.3
# 1              Steven Adams        C   28  MEM  76  75  26.3  2.8   5.1
# 2               Bam Adebayo        C   24  MIA  56  56  32.6  7.3  13.0
# 3              Santi Aldama       PF   21  MEM  32   0  11.3  1.7   4.1
# 4  Nickeil Alexander-Walker       SG   23  TOT  65  21  22.6  3.9  10.5
#
#      FG%  ...  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP     Salary
# 0  0.439  ...  18.5  0.4  2.1  2.5  0.070  -2.0  -0.6 -2.6  -0.2   2.840160
# 1  0.547  ...  12.0  3.8  3.0  6.8  0.163   1.0   1.0  2.0   2.0  17.926829
# 2  0.557  ...  25.0  3.6  3.5  7.2  0.188   1.7   2.1  3.8   2.7  30.351780
# 3  0.402  ...  18.4 -0.1  0.4  0.3  0.044  -4.2  -1.5 -5.7  -0.3   2.094120
# 4  0.372  ...  24.1 -1.1  1.1  0.1  0.003  -1.8  -1.1 -2.9  -0.3   5.009633
#
# [5 rows x 50 columns]

# %%
stats_cleaned.to_csv('NBA_2021-2022_Stats_Clean.csv', index = False)
